    'Consumer Price Index': [118.690502, 117.244195, 115.157303, 112.411557, 110.067009, 108.695722, 108.566932, 106.833849, 105.291505, 103.156842, 100.000000, 98.386420, 98.737477, 95.086992, 92.449705, 89.560532, 86.621678, 84.363079, 82.490467, 81.202568, 78.970721]
}
df = pd.DataFrame(data)
df
# Out:
#     date           GDP  Total Population  Unemployment Rate  Trade (% of GDP)  \
# 0   2020  2.106047e+13       331511512.0               8.05         23.383762
# 1   2019  2.138098e+13       328329953.0               3.67         26.451949
# 2   2018  2.053306e+13       326838199.0               3.90         27.610379
# 3   2017  1.947734e+13       325122128.0               4.36         27.279161
# 4   2016  1.869511e+13       323071755.0               4.87         26.586999
# 5   2015  1.820602e+13       320738994.0               5.28         27.812234
# 6   2014  1.755068e+13       318386329.0               6.17         29.998000
# 7   2013  1.684319e+13       316059947.0               7.37         30.002367
# 8   2012  1.625397e+13       313877662.0               8.07         30.681835
# 9   2011  1.559973e+13       311583481.0               8.95         30.842486
# 10  2010  1.504896e+13       309327143.0               9.63         28.219895
# ...

# %%
#1.Data preprocessing
df.describe().T
# Out:
#                                               count          mean  \
# date                                           21.0  2.010000e+03
# GDP                                            21.0  1.555534e+13
# Total Population                               21.0  3.080243e+08
# Unemployment Rate                              21.0  5.985238e+00
# Trade (% of GDP)                               21.0  2.674067e+01
# Health Expenditure (% of GDP)                  21.0  1.557583e+01
# Education Expenditure (% of GDP)               21.0  5.957740e+00
# Energy Use (kg of oil equivalent per capita)   16.0  7.436549e+03
# CO2 Emissions (metric tons per capita)         21.0  1.724647e+01
# Internet Users (% of population)               21.0  7.194013e+01
# Consumer Price Index                           21.0  9.971357e+01
#
#                                                        std           min  \
# date                                          6.204837e+00  2.000000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   date                                          21 non-null     int64
#  1   GDP                                           21 non-null     float64
#  2   Total Population                              21 non-null     float64
#  3   Unemployment Rate                             21 non-null     float64
#  4   Trade (% of GDP)                              21 non-null     float64
#  5   Health Expenditure (% of GDP)                 21 non-null     float64
#  6   Education Expenditure (% of GDP)              21 non-null     float64
#  7   Energy Use (kg of oil equivalent per capita)  16 non-null     float64
#  8   CO2 Emissions (metric tons per capita)        21 non-null     float64
# ...

# %%
df.isnull().sum()
# Out:
# date                                            0
# GDP                                             0
# Total Population                                0
# Unemployment Rate                               0
# Trade (% of GDP)                                0
# Health Expenditure (% of GDP)                   0
# Education Expenditure (% of GDP)                0
# Energy Use (kg of oil equivalent per capita)    5
# CO2 Emissions (metric tons per capita)          0
# Internet Users (% of population)                0
# Consumer Price Index                            0
# dtype: int64

# %%
#2 data cleaning, normalization,select variables
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# date                                            0
# GDP                                             0
# Total Population                                0
# Unemployment Rate                               0
# Trade (% of GDP)                                0
# Health Expenditure (% of GDP)                   0
# Education Expenditure (% of GDP)                0
# Energy Use (kg of oil equivalent per capita)    0
# CO2 Emissions (metric tons per capita)          0
# Internet Users (% of population)                0
# Consumer Price Index                            0
# dtype: int64

# %%
# Compute pairwise correlations
correlation_matrix = df.corr()
print("Correlation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                                                    date       GDP  \
# date                                          1.000000  0.991597
# GDP                                           0.991597  1.000000
# Total Population                              0.999215  0.990621
# Unemployment Rate                             0.530642  0.438051
# Trade (% of GDP)                              0.807499  0.830600
# Health Expenditure (% of GDP)                 0.937716  0.910657
# Education Expenditure (% of GDP)             -0.270695 -0.320418
# Energy Use (kg of oil equivalent per capita) -0.945930 -0.903638
# CO2 Emissions (metric tons per capita)       -0.966329 -0.932694
# Internet Users (% of population)              0.816532  0.838367
# Consumer Price Index                          0.994237  0.990889
#
#                                               Total Population  \
# date                                                  0.999215
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the correlation matrix using Seaborn
plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Show the heatmap
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Calculate Pearson correlation matrix
pearson_corr = df.corr(method='pearson')

# Calculate Spearman correlation matrix
spearman_corr = df.corr(method='spearman')

# Display the correlation matrices
print("Pearson Correlation Matrix:")
print(pearson_corr)
# Out:
# Pearson Correlation Matrix:
#                                                   date       GDP  \
# date                                          1.000000  0.991597
# GDP                                           0.991597  1.000000
# Total Population                              0.999215  0.990621
# Unemployment Rate                             0.530642  0.438051
# Trade (% of GDP)                              0.807499  0.830600
# Health Expenditure (% of GDP)                 0.937716  0.910657
# Education Expenditure (% of GDP)             -0.270695 -0.320418
# Energy Use (kg of oil equivalent per capita) -0.945930 -0.903638
# CO2 Emissions (metric tons per capita)       -0.966329 -0.932694
# Internet Users (% of population)              0.816532  0.838367
# Consumer Price Index                          0.994237  0.990889
#
#                                               Total Population  \
# date                                                  0.999215
# ...

# %%
#5 Correlation Network
import networkx as nx


def create_correlation_network(correlation_matrix, threshold):
    G = nx.Graph()
    edges = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i + 1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) > threshold:
                edges.append((correlation_matrix.columns[i], correlation_matrix.columns[j],
                              {'weight': abs(correlation_matrix.iloc[i, j])}))

    G.add_edges_from(edges)
    weights = [abs(G[u][v]['weight']) * 3 for u, v in G.edges()]

    plt.figure(figsize=(10, 8))
    pos = nx.spring_layout(G)  # Set layout for nodes

    nx.draw(G, pos, with_labels=True, node_size=1500, node_color='skyblue', edge_color='gray', width=weights)
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

    plt.title(f"Correlation Network (Threshold: {threshold})")
    plt.show()

# Set the threshold for correlation values to include in the network
threshold_value = 0.5  # Set your threshold here

# Creating the correlation network
create_correlation_network(pearson_corr, threshold_value)  # Change to spearman_corr if needed
